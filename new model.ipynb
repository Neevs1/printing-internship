# %%
# !pip install xgboost
# Out:
# ...
#    ---------------------------------------- 0.0/101.7 MB ? eta -:--:--
#     --------------------------------------- 1.3/101.7 MB 13.4 MB/s eta 0:00:08
#    - -------------------------------------- 3.7/101.7 MB 12.1 MB/s eta 0:00:09
#    -- ------------------------------------- 6.6/101.7 MB 13.0 MB/s eta 0:00:08
#    --- ------------------------------------ 9.4/101.7 MB 13.4 MB/s eta 0:00:07
#    ---- ----------------------------------- 12.1/101.7 MB 13.3 MB/s eta 0:00:07
#    ----- ---------------------------------- 14.9/101.7 MB 13.4 MB/s eta 0:00:07
#    ------ --------------------------------- 17.6/101.7 MB 13.5 MB/s eta 0:00:07
#    -------- ------------------------------- 20.4/101.7 MB 13.6 MB/s eta 0:00:06
#    --------- ------------------------------ 23.3/101.7 MB 13.5 MB/s eta 0:00:06
#    ---------- ----------------------------- 26.2/101.7 MB 13.6 MB/s eta 0:00:06
#    ----------- ---------------------------- 29.1/101.7 MB 13.7 MB/s eta 0:00:06
# ...

# %%
# !pip install xgboost

# %%
xgb_model = XGBRegressor(
    n_estimators=500,
    learning_rate=0.05,
    max_depth=6,
    subsample=0.8,
    colsample_bytree=0.8,
    reg_lambda=1,
    random_state=42,
    n_jobs=-1
)

# %%
xgb_pipe = Pipeline([
    ("prep", preprocessor),
    ("model", xgb_model)
])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 xgb_pipe = Pipeline([
#       2     ("prep", preprocessor),
#       3     ("model", xgb_model)
#       4 ])
#
# NameError: name 'Pipeline' is not defined
